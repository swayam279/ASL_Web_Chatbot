# %%
from usp.tree import sitemap_tree_for_homepage
import sys

sys.path.append("..")
from src.sitemap import create_sitemap, url_checker
# Out:
# d:\ASL_Web_Chatbot\.venv\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.1.0)/charset_normalizer (3.4.6) doesn't match a supported version!
#   warnings.warn(
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 import sys
#       4 sys.path.append("..")
# ----> 5 from src.sitemap import create_sitemap, url_checker
#
# File d:\ASL_Web_Chatbot\Notebooks\..\src\sitemap.py:3
#       1 from usp.tree import sitemap_tree_for_homepage
# ----> 3 from url_validator import url_checker
#       6 def create_sitemap(url: str) -> list[str]:
#       7     """
#       8     This function takes a url from user and fetches the sitemap of that website and returns a list containing all the urls in the sitemap.
#       9     """
#
# ModuleNotFoundError: No module named 'url_validator'

# %% [markdown]
# # Sitemap creator

# %%
create_sitemap('https://webscraper.io/test-sites/e-commerce/allinone/phones')
# Out:
# starting to scrape all the URLs from the website ...
# successfully fetched the sitemap of the website.
# ['https://docs.langchain.com/api-reference/auth-service-v2/authenticate',
#  'https://docs.langchain.com/api-reference/auth-service-v2/check-oauth-token-exists',
#  'https://docs.langchain.com/api-reference/auth-service-v2/check-workspace-slack-tokens-exist',
#  'https://docs.langchain.com/api-reference/auth-service-v2/create-mcp-oauth-provider',
#  'https://docs.langchain.com/api-reference/auth-service-v2/create-oauth-provider',
#  'https://docs.langchain.com/api-reference/auth-service-v2/delete-oauth-provider',
#  'https://docs.langchain.com/api-reference/auth-service-v2/delete-oauth-tokens-for-user',
#  'https://docs.langchain.com/api-reference/auth-service-v2/get-oauth-provider',
#  'https://docs.langchain.com/api-reference/auth-service-v2/list-oauth-providers',
#  'https://docs.langchain.com/api-reference/auth-service-v2/oauth-callback',
# ...
